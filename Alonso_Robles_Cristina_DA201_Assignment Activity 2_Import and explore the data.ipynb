# %%
# Import pandas.
import pandas as pd

# Read the Excel file.
# Assign a variable.
# Use the pd.read_excel() function.
# Specify the name of the Excel file.
nc = pd.read_excel('national_categories.xlsx')

# Print the DataFrame.
nc
# Out:
#        appointment_date icb_ons_code  \
# 0            2021-08-02    E54000050
# 1            2021-08-02    E54000050
# 2            2021-08-02    E54000050
# 3            2021-08-02    E54000050
# 4            2021-08-02    E54000050
# ...                 ...          ...
# 817389       2022-06-30    E54000054
# 817390       2022-06-30    E54000054
# 817391       2022-06-30    E54000054
# 817392       2022-06-30    E54000054
# 817393       2022-06-30    E54000054
#
#                              sub_icb_location_name            service_setting  \
# 0       NHS North East and North Cumbria ICB - 00L       Primary Care Network
# 1       NHS North East and North Cumbria ICB - 00L                      Other
# 2       NHS North East and North Cumbria ICB - 00L           General Practice
# 3       NHS North East and North Cumbria ICB - 00L           General Practice
# 4       NHS North East and North Cumbria ICB - 00L           General Practice
# ...                                            ...                        ...
# 817389              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
# 817390              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
# 817391              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
# 817392              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
# 817393              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
#
#                   context_type                       national_category  \
# 0       Care Related Encounter  Patient contact during Care Home Round
# 1       Care Related Encounter                         Planned Clinics
# 2       Care Related Encounter                              Home Visit
# 3       Care Related Encounter              General Consultation Acute
# 4       Care Related Encounter            Structured Medication Review
# ...                        ...                                     ...
# 817389  Care Related Encounter             Unplanned Clinical Activity
# 817390  Care Related Encounter                         Planned Clinics
# 817391  Care Related Encounter              Planned Clinical Procedure
# 817392  Care Related Encounter            General Consultation Routine
# 817393  Care Related Encounter              General Consultation Acute
#
#         count_of_appointments appointment_month
# 0                           3           2021-08
# 1                           7           2021-08
# 2                          79           2021-08
# 3                         725           2021-08
# 4                           2           2021-08
# ...                       ...               ...
# 817389                     12           2022-06
# 817390                      4           2022-06
# 817391                     92           2022-06
# 817392                      4           2022-06
# 817393                     19           2022-06
#
# [817394 rows x 8 columns]

# %%
# Read the CSV file.
# Assign a variable.
# Use the pd.read_csv() function.
# Specify the name of the CSV file.
ar = pd.read_csv('appointments_regional.csv')

# Print the DataFrame.
ar
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 0         E54000034           2020-01           Attended       GP
# 1         E54000034           2020-01           Attended       GP
# 2         E54000034           2020-01           Attended       GP
# 3         E54000034           2020-01           Attended       GP
# 4         E54000034           2020-01           Attended       GP
# ...             ...               ...                ...      ...
# 596816    E54000050           2022-06            Unknown  Unknown
# 596817    E54000050           2022-06            Unknown  Unknown
# 596818    E54000050           2022-06            Unknown  Unknown
# 596819    E54000050           2022-06            Unknown  Unknown
# 596820    E54000050           2022-06            Unknown  Unknown
#
#        appointment_mode time_between_book_and_appointment  \
# 0          Face-to-Face                             1 Day
# 1          Face-to-Face                    15  to 21 Days
# 2          Face-to-Face                       2 to 7 Days
# 3          Face-to-Face                    22  to 28 Days
# 4          Face-to-Face                     8  to 14 Days
# ...                 ...                               ...
# 596816          Unknown                       2 to 7 Days
# 596817          Unknown                    22  to 28 Days
# 596818          Unknown                     8  to 14 Days
# 596819          Unknown                 More than 28 Days
# 596820          Unknown                          Same Day
#
#         count_of_appointments
# 0                        8107
# 1                        6791
# 2                       20686
# 3                        4268
# 4                       11971
# ...                       ...
# 596816                     21
# 596817                      8
# 596818                     28
# 596819                     17
# 596820                     10
#
# [596821 rows x 7 columns]

# %%
# Read the CSV file.
# Assign a variable.
# Use the pd.read_csv() function.
# Specify the name of the CSV file.
ad = pd.read_csv('actual_duration.csv')

# Print the DataFrame.
ad
# Out:
#        sub_icb_location_code sub_icb_location_ons_code  \
# 0                        00L                 E38000130
# 1                        00L                 E38000130
# 2                        00L                 E38000130
# 3                        00L                 E38000130
# 4                        00L                 E38000130
# ...                      ...                       ...
# 137788                 X2C4Y                 E38000254
# 137789                 X2C4Y                 E38000254
# 137790                 X2C4Y                 E38000254
# 137791                 X2C4Y                 E38000254
# 137792                 X2C4Y                 E38000254
#
#                              sub_icb_location_name icb_ons_code  \
# 0       NHS North East and North Cumbria ICB - 00L    E54000050
# 1       NHS North East and North Cumbria ICB - 00L    E54000050
# 2       NHS North East and North Cumbria ICB - 00L    E54000050
# 3       NHS North East and North Cumbria ICB - 00L    E54000050
# 4       NHS North East and North Cumbria ICB - 00L    E54000050
# ...                                            ...          ...
# 137788              NHS West Yorkshire ICB - X2C4Y    E54000054
# 137789              NHS West Yorkshire ICB - X2C4Y    E54000054
# 137790              NHS West Yorkshire ICB - X2C4Y    E54000054
# 137791              NHS West Yorkshire ICB - X2C4Y    E54000054
# 137792              NHS West Yorkshire ICB - X2C4Y    E54000054
#
#        region_ons_code appointment_date         actual_duration  \
# 0            E40000012        01-Dec-21           31-60 Minutes
# 1            E40000012        01-Dec-21           21-30 Minutes
# 2            E40000012        01-Dec-21            6-10 Minutes
# 3            E40000012        01-Dec-21  Unknown / Data Quality
# 4            E40000012        01-Dec-21           16-20 Minutes
# ...                ...              ...                     ...
# 137788       E40000012        30-Jun-22           31-60 Minutes
# 137789       E40000012        30-Jun-22           21-30 Minutes
# 137790       E40000012        30-Jun-22           16-20 Minutes
# 137791       E40000012        30-Jun-22           11-15 Minutes
# 137792       E40000012        30-Jun-22             1-5 Minutes
#
#         count_of_appointments
# 0                         364
# 1                         619
# 2                        1698
# 3                        1277
# 4                         730
# ...                       ...
# 137788                    430
# 137789                    751
# 137790                    921
# 137791                   1439
# 137792                   1739
#
# [137793 rows x 8 columns]

# %%
# Print the number of columns of each data set.
print(nc.columns)
print(ar.columns)
print(ad.columns)
# Out:
# Index(['appointment_date', 'icb_ons_code', 'sub_icb_location_name',
#        'service_setting', 'context_type', 'national_category',
#        'count_of_appointments', 'appointment_month'],
#       dtype='object')
# Index(['icb_ons_code', 'appointment_month', 'appointment_status', 'hcp_type',
#        'appointment_mode', 'time_between_book_and_appointment',
#        'count_of_appointments'],
#       dtype='object')
# Index(['sub_icb_location_code', 'sub_icb_location_ons_code',
#        'sub_icb_location_name', 'icb_ons_code', 'region_ons_code',
#        'appointment_date', 'actual_duration', 'count_of_appointments'],
#       dtype='object')

# %%
# Determine shape of the national_category data set.
print(nc.shape)
print(nc.dtypes)
# Out:
# (817394, 8)
# appointment_date         datetime64[ns]
# icb_ons_code                     object
# sub_icb_location_name            object
# service_setting                  object
# context_type                     object
# national_category                object
# count_of_appointments             int64
# appointment_month                object
# dtype: object

# %%
# Determine shape of the appointments regional data set.
print(ar.shape)
print(ar.dtypes)
# Out:
# (596821, 7)
# icb_ons_code                         object
# appointment_month                    object
# appointment_status                   object
# hcp_type                             object
# appointment_mode                     object
# time_between_book_and_appointment    object
# count_of_appointments                 int64
# dtype: object

# %%
# Determine shape of the actual_duration data set.
print(ad.shape)
print(ad.dtypes)
# Out:
# (137793, 8)
# sub_icb_location_code        object
# sub_icb_location_ons_code    object
# sub_icb_location_name        object
# icb_ons_code                 object
# region_ons_code              object
# appointment_date             object
# actual_duration              object
# count_of_appointments         int64
# dtype: object

# %%
# Print the entire 'ad' DataFrame to perform a sense-check.
print(ad)
# Out:
#        sub_icb_location_code sub_icb_location_ons_code  \
# 0                        00L                 E38000130
# 1                        00L                 E38000130
# 2                        00L                 E38000130
# 3                        00L                 E38000130
# 4                        00L                 E38000130
# ...                      ...                       ...
# 137788                 X2C4Y                 E38000254
# 137789                 X2C4Y                 E38000254
# 137790                 X2C4Y                 E38000254
# 137791                 X2C4Y                 E38000254
# 137792                 X2C4Y                 E38000254
#
#                              sub_icb_location_name icb_ons_code  \
# 0       NHS North East and North Cumbria ICB - 00L    E54000050
# 1       NHS North East and North Cumbria ICB - 00L    E54000050
# 2       NHS North East and North Cumbria ICB - 00L    E54000050
# 3       NHS North East and North Cumbria ICB - 00L    E54000050
# 4       NHS North East and North Cumbria ICB - 00L    E54000050
# ...                                            ...          ...
# 137788              NHS West Yorkshire ICB - X2C4Y    E54000054
# 137789              NHS West Yorkshire ICB - X2C4Y    E54000054
# 137790              NHS West Yorkshire ICB - X2C4Y    E54000054
# 137791              NHS West Yorkshire ICB - X2C4Y    E54000054
# 137792              NHS West Yorkshire ICB - X2C4Y    E54000054
#
#        region_ons_code appointment_date         actual_duration  \
# 0            E40000012        01-Dec-21           31-60 Minutes
# 1            E40000012        01-Dec-21           21-30 Minutes
# 2            E40000012        01-Dec-21            6-10 Minutes
# 3            E40000012        01-Dec-21  Unknown / Data Quality
# 4            E40000012        01-Dec-21           16-20 Minutes
# ...                ...              ...                     ...
# 137788       E40000012        30-Jun-22           31-60 Minutes
# 137789       E40000012        30-Jun-22           21-30 Minutes
# 137790       E40000012        30-Jun-22           16-20 Minutes
# 137791       E40000012        30-Jun-22           11-15 Minutes
# 137792       E40000012        30-Jun-22             1-5 Minutes
#
#         count_of_appointments
# 0                         364
# 1                         619
# 2                        1698
# 3                        1277
# 4                         730
# ...                       ...
# 137788                    430
# 137789                    751
# 137790                    921
# 137791                   1439
# 137792                   1739
#
# [137793 rows x 8 columns]

# %%
# Print the entire 'nc' DataFrame to perform a sense-check.
print(nc)
# Out:
#        appointment_date icb_ons_code  \
# 0            2021-08-02    E54000050
# 1            2021-08-02    E54000050
# 2            2021-08-02    E54000050
# 3            2021-08-02    E54000050
# 4            2021-08-02    E54000050
# ...                 ...          ...
# 817389       2022-06-30    E54000054
# 817390       2022-06-30    E54000054
# 817391       2022-06-30    E54000054
# 817392       2022-06-30    E54000054
# 817393       2022-06-30    E54000054
#
#                              sub_icb_location_name            service_setting  \
# 0       NHS North East and North Cumbria ICB - 00L       Primary Care Network
# 1       NHS North East and North Cumbria ICB - 00L                      Other
# 2       NHS North East and North Cumbria ICB - 00L           General Practice
# 3       NHS North East and North Cumbria ICB - 00L           General Practice
# 4       NHS North East and North Cumbria ICB - 00L           General Practice
# ...                                            ...                        ...
# 817389              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
# 817390              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
# 817391              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
# 817392              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
# 817393              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
#
#                   context_type                       national_category  \
# 0       Care Related Encounter  Patient contact during Care Home Round
# 1       Care Related Encounter                         Planned Clinics
# 2       Care Related Encounter                              Home Visit
# 3       Care Related Encounter              General Consultation Acute
# 4       Care Related Encounter            Structured Medication Review
# ...                        ...                                     ...
# 817389  Care Related Encounter             Unplanned Clinical Activity
# 817390  Care Related Encounter                         Planned Clinics
# 817391  Care Related Encounter              Planned Clinical Procedure
# 817392  Care Related Encounter            General Consultation Routine
# 817393  Care Related Encounter              General Consultation Acute
#
#         count_of_appointments appointment_month
# 0                           3           2021-08
# 1                           7           2021-08
# 2                          79           2021-08
# 3                         725           2021-08
# 4                           2           2021-08
# ...                       ...               ...
# 817389                     12           2022-06
# 817390                      4           2022-06
# 817391                     92           2022-06
# 817392                      4           2022-06
# 817393                     19           2022-06
#
# [817394 rows x 8 columns]

# %%
# Print the entire 'ar' DataFrame to perform a sense-check.
print(ar)
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 0         E54000034           2020-01           Attended       GP
# 1         E54000034           2020-01           Attended       GP
# 2         E54000034           2020-01           Attended       GP
# 3         E54000034           2020-01           Attended       GP
# 4         E54000034           2020-01           Attended       GP
# ...             ...               ...                ...      ...
# 596816    E54000050           2022-06            Unknown  Unknown
# 596817    E54000050           2022-06            Unknown  Unknown
# 596818    E54000050           2022-06            Unknown  Unknown
# 596819    E54000050           2022-06            Unknown  Unknown
# 596820    E54000050           2022-06            Unknown  Unknown
#
#        appointment_mode time_between_book_and_appointment  \
# 0          Face-to-Face                             1 Day
# 1          Face-to-Face                    15  to 21 Days
# 2          Face-to-Face                       2 to 7 Days
# 3          Face-to-Face                    22  to 28 Days
# 4          Face-to-Face                     8  to 14 Days
# ...                 ...                               ...
# 596816          Unknown                       2 to 7 Days
# 596817          Unknown                    22  to 28 Days
# 596818          Unknown                     8  to 14 Days
# 596819          Unknown                 More than 28 Days
# 596820          Unknown                          Same Day
#
#         count_of_appointments
# 0                        8107
# 1                        6791
# 2                       20686
# 3                        4268
# 4                       11971
# ...                       ...
# 596816                     21
# 596817                      8
# 596818                     28
# 596819                     17
# 596820                     10
#
# [596821 rows x 7 columns]

# %%
# Identify the number of missing values in the 'nc' data set.
nc = pd.read_excel('national_categories.xlsx')
nc.head()
# Out:
#   appointment_date icb_ons_code                       sub_icb_location_name  \
# 0       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 1       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 2       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 3       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
# 4       2021-08-02    E54000050  NHS North East and North Cumbria ICB - 00L
#
#         service_setting            context_type  \
# 0  Primary Care Network  Care Related Encounter
# 1                 Other  Care Related Encounter
# 2      General Practice  Care Related Encounter
# 3      General Practice  Care Related Encounter
# 4      General Practice  Care Related Encounter
#
#                         national_category  count_of_appointments  \
# 0  Patient contact during Care Home Round                      3
# 1                         Planned Clinics                      7
# 2                              Home Visit                     79
# 3              General Consultation Acute                    725
# 4            Structured Medication Review                      2
#
#   appointment_month
# 0           2021-08
# 1           2021-08
# 2           2021-08
# 3           2021-08
# 4           2021-08

# %%
nc_na = nc[nc.isna().any(axis=1)]
nc_na.shape
# Out:
# (0, 8)

# %%
# Identify the number of missing values in the 'ad' data set.
ad = pd.read_csv('actual_duration.csv')
ad.head()
# Out:
#   sub_icb_location_code sub_icb_location_ons_code  \
# 0                   00L                 E38000130
# 1                   00L                 E38000130
# 2                   00L                 E38000130
# 3                   00L                 E38000130
# 4                   00L                 E38000130
#
#                         sub_icb_location_name icb_ons_code region_ons_code  \
# 0  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 1  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 2  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 3  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
# 4  NHS North East and North Cumbria ICB - 00L    E54000050       E40000012
#
#   appointment_date         actual_duration  count_of_appointments
# 0        01-Dec-21           31-60 Minutes                    364
# 1        01-Dec-21           21-30 Minutes                    619
# 2        01-Dec-21            6-10 Minutes                   1698
# 3        01-Dec-21  Unknown / Data Quality                   1277
# 4        01-Dec-21           16-20 Minutes                    730

# %%
ad_na = ad[ad.isna().any(axis=1)]
ad_na.shape
# Out:
# (0, 8)

# %%
# Identify the number of missing values in the 'ar' data set.
ar = pd.read_csv('appointments_regional.csv')
ar.head()
# Out:
#   icb_ons_code appointment_month appointment_status hcp_type appointment_mode  \
# 0    E54000034           2020-01           Attended       GP     Face-to-Face
# 1    E54000034           2020-01           Attended       GP     Face-to-Face
# 2    E54000034           2020-01           Attended       GP     Face-to-Face
# 3    E54000034           2020-01           Attended       GP     Face-to-Face
# 4    E54000034           2020-01           Attended       GP     Face-to-Face
#
#   time_between_book_and_appointment  count_of_appointments
# 0                             1 Day                   8107
# 1                    15  to 21 Days                   6791
# 2                       2 to 7 Days                  20686
# 3                    22  to 28 Days                   4268
# 4                     8  to 14 Days                  11971

# %%
ar_na = ar[ar.isna().any(axis=1)]
ar_na.shape
# Out:
# (0, 7)

# %%
# Import the necessary packages.
import pandas as pd

# Read the Excel file.
# Assign a variable.
# Use the pd.read_excel() function.
# Specify the name of the Excel file.
nc = pd.read_excel('national_categories.xlsx')

# Print the DataFrame.
nc
# Out:
#        appointment_date icb_ons_code  \
# 0            2021-08-02    E54000050
# 1            2021-08-02    E54000050
# 2            2021-08-02    E54000050
# 3            2021-08-02    E54000050
# 4            2021-08-02    E54000050
# ...                 ...          ...
# 817389       2022-06-30    E54000054
# 817390       2022-06-30    E54000054
# 817391       2022-06-30    E54000054
# 817392       2022-06-30    E54000054
# 817393       2022-06-30    E54000054
#
#                              sub_icb_location_name            service_setting  \
# 0       NHS North East and North Cumbria ICB - 00L       Primary Care Network
# 1       NHS North East and North Cumbria ICB - 00L                      Other
# 2       NHS North East and North Cumbria ICB - 00L           General Practice
# 3       NHS North East and North Cumbria ICB - 00L           General Practice
# 4       NHS North East and North Cumbria ICB - 00L           General Practice
# ...                                            ...                        ...
# 817389              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
# 817390              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
# 817391              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
# 817392              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
# 817393              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
#
#                   context_type                       national_category  \
# 0       Care Related Encounter  Patient contact during Care Home Round
# 1       Care Related Encounter                         Planned Clinics
# 2       Care Related Encounter                              Home Visit
# 3       Care Related Encounter              General Consultation Acute
# 4       Care Related Encounter            Structured Medication Review
# ...                        ...                                     ...
# 817389  Care Related Encounter             Unplanned Clinical Activity
# 817390  Care Related Encounter                         Planned Clinics
# 817391  Care Related Encounter              Planned Clinical Procedure
# 817392  Care Related Encounter            General Consultation Routine
# 817393  Care Related Encounter              General Consultation Acute
#
#         count_of_appointments appointment_month
# 0                           3           2021-08
# 1                           7           2021-08
# 2                          79           2021-08
# 3                         725           2021-08
# 4                           2           2021-08
# ...                       ...               ...
# 817389                     12           2022-06
# 817390                      4           2022-06
# 817391                     92           2022-06
# 817392                      4           2022-06
# 817393                     19           2022-06
#
# [817394 rows x 8 columns]

# %%
# Read the CSV file.
# Assign a variable.
# Use the pd.read_csv() function.
# Specify the name of the CSV file.
ar = pd.read_csv('appointments_regional.csv')

# Print the DataFrame.
ar
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 0         E54000034           2020-01           Attended       GP
# 1         E54000034           2020-01           Attended       GP
# 2         E54000034           2020-01           Attended       GP
# 3         E54000034           2020-01           Attended       GP
# 4         E54000034           2020-01           Attended       GP
# ...             ...               ...                ...      ...
# 596816    E54000050           2022-06            Unknown  Unknown
# 596817    E54000050           2022-06            Unknown  Unknown
# 596818    E54000050           2022-06            Unknown  Unknown
# 596819    E54000050           2022-06            Unknown  Unknown
# 596820    E54000050           2022-06            Unknown  Unknown
#
#        appointment_mode time_between_book_and_appointment  \
# 0          Face-to-Face                             1 Day
# 1          Face-to-Face                    15  to 21 Days
# 2          Face-to-Face                       2 to 7 Days
# 3          Face-to-Face                    22  to 28 Days
# 4          Face-to-Face                     8  to 14 Days
# ...                 ...                               ...
# 596816          Unknown                       2 to 7 Days
# 596817          Unknown                    22  to 28 Days
# 596818          Unknown                     8  to 14 Days
# 596819          Unknown                 More than 28 Days
# 596820          Unknown                          Same Day
#
#         count_of_appointments
# 0                        8107
# 1                        6791
# 2                       20686
# 3                        4268
# 4                       11971
# ...                       ...
# 596816                     21
# 596817                      8
# 596818                     28
# 596819                     17
# 596820                     10
#
# [596821 rows x 7 columns]

# %%
# Read the CSV file.
# Assign a variable.
# Use the pd.read_csv() function.
# Specify the name of the CSV file.
ad = pd.read_csv('actual_duration.csv')

# Print the DataFrame.
ad
# Out:
#        sub_icb_location_code sub_icb_location_ons_code  \
# 0                        00L                 E38000130
# 1                        00L                 E38000130
# 2                        00L                 E38000130
# 3                        00L                 E38000130
# 4                        00L                 E38000130
# ...                      ...                       ...
# 137788                 X2C4Y                 E38000254
# 137789                 X2C4Y                 E38000254
# 137790                 X2C4Y                 E38000254
# 137791                 X2C4Y                 E38000254
# 137792                 X2C4Y                 E38000254
#
#                              sub_icb_location_name icb_ons_code  \
# 0       NHS North East and North Cumbria ICB - 00L    E54000050
# 1       NHS North East and North Cumbria ICB - 00L    E54000050
# 2       NHS North East and North Cumbria ICB - 00L    E54000050
# 3       NHS North East and North Cumbria ICB - 00L    E54000050
# 4       NHS North East and North Cumbria ICB - 00L    E54000050
# ...                                            ...          ...
# 137788              NHS West Yorkshire ICB - X2C4Y    E54000054
# 137789              NHS West Yorkshire ICB - X2C4Y    E54000054
# 137790              NHS West Yorkshire ICB - X2C4Y    E54000054
# 137791              NHS West Yorkshire ICB - X2C4Y    E54000054
# 137792              NHS West Yorkshire ICB - X2C4Y    E54000054
#
#        region_ons_code appointment_date         actual_duration  \
# 0            E40000012        01-Dec-21           31-60 Minutes
# 1            E40000012        01-Dec-21           21-30 Minutes
# 2            E40000012        01-Dec-21            6-10 Minutes
# 3            E40000012        01-Dec-21  Unknown / Data Quality
# 4            E40000012        01-Dec-21           16-20 Minutes
# ...                ...              ...                     ...
# 137788       E40000012        30-Jun-22           31-60 Minutes
# 137789       E40000012        30-Jun-22           21-30 Minutes
# 137790       E40000012        30-Jun-22           16-20 Minutes
# 137791       E40000012        30-Jun-22           11-15 Minutes
# 137792       E40000012        30-Jun-22             1-5 Minutes
#
#         count_of_appointments
# 0                         364
# 1                         619
# 2                        1698
# 3                        1277
# 4                         730
# ...                       ...
# 137788                    430
# 137789                    751
# 137790                    921
# 137791                   1439
# 137792                   1739
#
# [137793 rows x 8 columns]

# %%
# Determine the sum of missing values in the 'ad' DataFrame.
# There are wrong values in the 'actual_duration' column, identified as: 'Unknown / Data Quality'.
# Python does not identify them as missing values.
# I will use some filters later on in my analysis to filter these wrong values out of my analysis.

ad['actual_duration'].isnull().sum()
# Out:
# 0

# %%
# Determine the sum of missing values in the 'nc' DataFrame.
# There are wrong values in the 'service_setting' column, identified as 'Unmapped'.
# There are also wrong values in the 'context_type' and 'national_category' columns, identified as 'Inconsistent Mapping' and 'Unmapped'.
# Python does not identify them as missing values because they are the same data type.
# I will use some filters later on in my analysis to filter these wrong values out of my analysis.

nc['service_setting'].isnull().sum()
nc['context_type'].isnull().sum()
nc['national_category'].isnull().sum()
# Out:
# 0

# %%
# Determine the sum of missing values in the 'ar' DataFrame.
# There are wrong values in the 'appointment_status' and in the 'hcp_type' columns, identified as 'Unknown'. 
# There are also wrong values in the 'time_between_book_and_appointment' column, identified as 'Unknown / Data Quality'.
# Python does not identify them as missing values.
# I will use some filters later on in my analysis to filter these wrong values out of my analysis.

ar['appointment_status'].isnull().sum()
ar['hcp_type'].isnull().sum()
ar['time_between_book_and_appointment'].isnull().sum()
# Out:
# 0

# %%
# Filter the 'ar' DataFrame according to wrong values.
# There are wrong values in the 'appointment_status', identified as 'Unknown'. 

ar[ar['appointment_status'].str.contains("Unknown")]
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 124       E54000034           2020-01            Unknown       GP
# 125       E54000034           2020-01            Unknown       GP
# 126       E54000034           2020-01            Unknown       GP
# 127       E54000034           2020-01            Unknown       GP
# 128       E54000034           2020-01            Unknown       GP
# ...             ...               ...                ...      ...
# 596816    E54000050           2022-06            Unknown  Unknown
# 596817    E54000050           2022-06            Unknown  Unknown
# 596818    E54000050           2022-06            Unknown  Unknown
# 596819    E54000050           2022-06            Unknown  Unknown
# 596820    E54000050           2022-06            Unknown  Unknown
#
#        appointment_mode time_between_book_and_appointment  \
# 124        Face-to-Face                             1 Day
# 125        Face-to-Face                    15  to 21 Days
# 126        Face-to-Face                       2 to 7 Days
# 127        Face-to-Face                    22  to 28 Days
# 128        Face-to-Face                     8  to 14 Days
# ...                 ...                               ...
# 596816          Unknown                       2 to 7 Days
# 596817          Unknown                    22  to 28 Days
# 596818          Unknown                     8  to 14 Days
# 596819          Unknown                 More than 28 Days
# 596820          Unknown                          Same Day
#
#         count_of_appointments
# 124                       264
# 125                       706
# 126                       682
# 127                       702
# 128                       682
# ...                       ...
# 596816                     21
# 596817                      8
# 596818                     28
# 596819                     17
# 596820                     10
#
# [201324 rows x 7 columns]

# %%
# Filter the 'ar' DataFrame according to wrong values.
# There are wrong values in the 'hcp_type', identified as 'Unknown'. 

ar[ar['hcp_type'].str.contains("Unknown")]
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 58        E54000034           2020-01           Attended  Unknown
# 59        E54000034           2020-01           Attended  Unknown
# 60        E54000034           2020-01           Attended  Unknown
# 61        E54000034           2020-01           Attended  Unknown
# 62        E54000034           2020-01           Attended  Unknown
# ...             ...               ...                ...      ...
# 596816    E54000050           2022-06            Unknown  Unknown
# 596817    E54000050           2022-06            Unknown  Unknown
# 596818    E54000050           2022-06            Unknown  Unknown
# 596819    E54000050           2022-06            Unknown  Unknown
# 596820    E54000050           2022-06            Unknown  Unknown
#
#        appointment_mode time_between_book_and_appointment  \
# 58         Face-to-Face                             1 Day
# 59         Face-to-Face                    15  to 21 Days
# 60         Face-to-Face                       2 to 7 Days
# 61         Face-to-Face                    22  to 28 Days
# 62         Face-to-Face                     8  to 14 Days
# ...                 ...                               ...
# 596816          Unknown                       2 to 7 Days
# 596817          Unknown                    22  to 28 Days
# 596818          Unknown                     8  to 14 Days
# 596819          Unknown                 More than 28 Days
# 596820          Unknown                          Same Day
#
#         count_of_appointments
# 58                         77
# 59                          3
# 60                         80
# 61                          1
# 62                         29
# ...                       ...
# 596816                     21
# 596817                      8
# 596818                     28
# 596819                     17
# 596820                     10
#
# [129228 rows x 7 columns]

# %%
# Filter the 'ar' DataFrame according to wrong values.
# There are wrong values in the 'time_between_book_and_appointment' column, identified as 'Unknown / Data Quality'.
ar[ar['time_between_book_and_appointment'].str.contains('Unknown / Data Quality')]
# Out:
#        icb_ons_code appointment_month appointment_status  \
# 21        E54000034           2020-01           Attended
# 36        E54000034           2020-01           Attended
# 119       E54000034           2020-01                DNA
# 131       E54000034           2020-01            Unknown
# 144       E54000034           2020-01            Unknown
# ...             ...               ...                ...
# 596651    E54000050           2022-06           Attended
# 596658    E54000050           2022-06           Attended
# 596673    E54000050           2022-06           Attended
# 596698    E54000050           2022-06           Attended
# 596784    E54000050           2022-06            Unknown
#
#                     hcp_type appointment_mode  \
# 21                        GP        Telephone
# 36      Other Practice staff     Face-to-Face
# 119     Other Practice staff          Unknown
# 131                       GP     Face-to-Face
# 144                       GP        Telephone
# ...                      ...              ...
# 596651                    GP     Face-to-Face
# 596658                    GP       Home Visit
# 596673  Other Practice staff     Face-to-Face
# 596698               Unknown     Face-to-Face
# 596784  Other Practice staff     Face-to-Face
#
#        time_between_book_and_appointment  count_of_appointments
# 21                Unknown / Data Quality                      2
# 36                Unknown / Data Quality                      8
# 119               Unknown / Data Quality                      2
# 131               Unknown / Data Quality                     30
# 144               Unknown / Data Quality                      3
# ...                                  ...                    ...
# 596651            Unknown / Data Quality                     29
# 596658            Unknown / Data Quality                      4
# 596673            Unknown / Data Quality                      2
# 596698            Unknown / Data Quality                      1
# 596784            Unknown / Data Quality                      2
#
# [29687 rows x 7 columns]

# %%
# Filter the 'ad' DataFrame according to wrong values.
# There are wrong values in the 'actual_duration' column, identified as'Unknown / Data Quality'.


ad[ad['actual_duration'].str.contains('Unknown / Data Quality')]
# Out:
#        sub_icb_location_code sub_icb_location_ons_code  \
# 3                        00L                 E38000130
# 8                        00L                 E38000130
# 17                       00L                 E38000130
# 24                       00L                 E38000130
# 34                       00L                 E38000130
# ...                      ...                       ...
# 137758                 X2C4Y                 E38000254
# 137765                 X2C4Y                 E38000254
# 137772                 X2C4Y                 E38000254
# 137779                 X2C4Y                 E38000254
# 137786                 X2C4Y                 E38000254
#
#                              sub_icb_location_name icb_ons_code  \
# 3       NHS North East and North Cumbria ICB - 00L    E54000050
# 8       NHS North East and North Cumbria ICB - 00L    E54000050
# 17      NHS North East and North Cumbria ICB - 00L    E54000050
# 24      NHS North East and North Cumbria ICB - 00L    E54000050
# 34      NHS North East and North Cumbria ICB - 00L    E54000050
# ...                                            ...          ...
# 137758              NHS West Yorkshire ICB - X2C4Y    E54000054
# 137765              NHS West Yorkshire ICB - X2C4Y    E54000054
# 137772              NHS West Yorkshire ICB - X2C4Y    E54000054
# 137779              NHS West Yorkshire ICB - X2C4Y    E54000054
# 137786              NHS West Yorkshire ICB - X2C4Y    E54000054
#
#        region_ons_code appointment_date         actual_duration  \
# 3            E40000012        01-Dec-21  Unknown / Data Quality
# 8            E40000012        02-Dec-21  Unknown / Data Quality
# 17           E40000012        03-Dec-21  Unknown / Data Quality
# 24           E40000012        04-Dec-21  Unknown / Data Quality
# 34           E40000012        06-Dec-21  Unknown / Data Quality
# ...                ...              ...                     ...
# 137758       E40000012        25-Jun-22  Unknown / Data Quality
# 137765       E40000012        27-Jun-22  Unknown / Data Quality
# 137772       E40000012        28-Jun-22  Unknown / Data Quality
# 137779       E40000012        29-Jun-22  Unknown / Data Quality
# 137786       E40000012        30-Jun-22  Unknown / Data Quality
#
#         count_of_appointments
# 3                        1277
# 8                        1391
# 17                       1237
# 24                         41
# 34                       1502
# ...                       ...
# 137758                     60
# 137765                   2616
# 137772                   2815
# 137779                   2256
# 137786                   2463
#
# [20161 rows x 8 columns]

# %%
# Filter the 'nc' DataFrame according to wrong values.
# There are wrong values in the 'service_setting' column, identified as 'Unmapped'.


nc[nc['service_setting'].str.contains('Unmapped')]
# Out:
#        appointment_date icb_ons_code  \
# 6            2021-08-02    E54000050
# 36           2021-08-03    E54000050
# 65           2021-08-04    E54000050
# 92           2021-08-05    E54000050
# 130          2021-08-06    E54000050
# ...                 ...          ...
# 817213       2022-06-25    E54000054
# 817253       2022-06-27    E54000054
# 817279       2022-06-28    E54000054
# 817305       2022-06-29    E54000054
# 817349       2022-06-30    E54000054
#
#                              sub_icb_location_name service_setting  \
# 6       NHS North East and North Cumbria ICB - 00L        Unmapped
# 36      NHS North East and North Cumbria ICB - 00L        Unmapped
# 65      NHS North East and North Cumbria ICB - 00L        Unmapped
# 92      NHS North East and North Cumbria ICB - 00L        Unmapped
# 130     NHS North East and North Cumbria ICB - 00L        Unmapped
# ...                                            ...             ...
# 817213              NHS West Yorkshire ICB - X2C4Y        Unmapped
# 817253              NHS West Yorkshire ICB - X2C4Y        Unmapped
# 817279              NHS West Yorkshire ICB - X2C4Y        Unmapped
# 817305              NHS West Yorkshire ICB - X2C4Y        Unmapped
# 817349              NHS West Yorkshire ICB - X2C4Y        Unmapped
#
#        context_type national_category  count_of_appointments appointment_month
# 6          Unmapped          Unmapped                    372           2021-08
# 36         Unmapped          Unmapped                    362           2021-08
# 65         Unmapped          Unmapped                    336           2021-08
# 92         Unmapped          Unmapped                    394           2021-08
# 130        Unmapped          Unmapped                    302           2021-08
# ...             ...               ...                    ...               ...
# 817213     Unmapped          Unmapped                      1           2022-06
# 817253     Unmapped          Unmapped                    225           2022-06
# 817279     Unmapped          Unmapped                    176           2022-06
# 817305     Unmapped          Unmapped                    146           2022-06
# 817349     Unmapped          Unmapped                    186           2022-06
#
# [27419 rows x 8 columns]

# %%
# Filter the 'nc' DataFrame according to wrong values.
# There are also wrong values in the 'context_type' column, identified as 'Inconsistent Mapping' and 'Unmapped'.

nc[nc['context_type'].str.contains('Unmapped')]
# Out:
#        appointment_date icb_ons_code  \
# 6            2021-08-02    E54000050
# 36           2021-08-03    E54000050
# 65           2021-08-04    E54000050
# 92           2021-08-05    E54000050
# 130          2021-08-06    E54000050
# ...                 ...          ...
# 817213       2022-06-25    E54000054
# 817253       2022-06-27    E54000054
# 817279       2022-06-28    E54000054
# 817305       2022-06-29    E54000054
# 817349       2022-06-30    E54000054
#
#                              sub_icb_location_name service_setting  \
# 6       NHS North East and North Cumbria ICB - 00L        Unmapped
# 36      NHS North East and North Cumbria ICB - 00L        Unmapped
# 65      NHS North East and North Cumbria ICB - 00L        Unmapped
# 92      NHS North East and North Cumbria ICB - 00L        Unmapped
# 130     NHS North East and North Cumbria ICB - 00L        Unmapped
# ...                                            ...             ...
# 817213              NHS West Yorkshire ICB - X2C4Y        Unmapped
# 817253              NHS West Yorkshire ICB - X2C4Y        Unmapped
# 817279              NHS West Yorkshire ICB - X2C4Y        Unmapped
# 817305              NHS West Yorkshire ICB - X2C4Y        Unmapped
# 817349              NHS West Yorkshire ICB - X2C4Y        Unmapped
#
#        context_type national_category  count_of_appointments appointment_month
# 6          Unmapped          Unmapped                    372           2021-08
# 36         Unmapped          Unmapped                    362           2021-08
# 65         Unmapped          Unmapped                    336           2021-08
# 92         Unmapped          Unmapped                    394           2021-08
# 130        Unmapped          Unmapped                    302           2021-08
# ...             ...               ...                    ...               ...
# 817213     Unmapped          Unmapped                      1           2022-06
# 817253     Unmapped          Unmapped                    225           2022-06
# 817279     Unmapped          Unmapped                    176           2022-06
# 817305     Unmapped          Unmapped                    146           2022-06
# 817349     Unmapped          Unmapped                    186           2022-06
#
# [27419 rows x 8 columns]

# %%
nc[nc['context_type'].str.contains('Inconsistent Mapping')]
# Out:
#        appointment_date icb_ons_code  \
# 12           2021-08-02    E54000050
# 15           2021-08-02    E54000050
# 17           2021-08-02    E54000050
# 38           2021-08-03    E54000050
# 43           2021-08-03    E54000050
# ...                 ...          ...
# 817344       2022-06-29    E54000054
# 817350       2022-06-30    E54000054
# 817361       2022-06-30    E54000054
# 817370       2022-06-30    E54000054
# 817388       2022-06-30    E54000054
#
#                              sub_icb_location_name            service_setting  \
# 12      NHS North East and North Cumbria ICB - 00L           General Practice
# 15      NHS North East and North Cumbria ICB - 00L  Extended Access Provision
# 17      NHS North East and North Cumbria ICB - 00L                      Other
# 38      NHS North East and North Cumbria ICB - 00L                      Other
# 43      NHS North East and North Cumbria ICB - 00L           General Practice
# ...                                            ...                        ...
# 817344              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
# 817350              NHS West Yorkshire ICB - X2C4Y       Primary Care Network
# 817361              NHS West Yorkshire ICB - X2C4Y                      Other
# 817370              NHS West Yorkshire ICB - X2C4Y           General Practice
# 817388              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
#
#                 context_type     national_category  count_of_appointments  \
# 12      Inconsistent Mapping  Inconsistent Mapping                    619
# 15      Inconsistent Mapping  Inconsistent Mapping                      1
# 17      Inconsistent Mapping  Inconsistent Mapping                    194
# 38      Inconsistent Mapping  Inconsistent Mapping                    170
# 43      Inconsistent Mapping  Inconsistent Mapping                    610
# ...                      ...                   ...                    ...
# 817344  Inconsistent Mapping  Inconsistent Mapping                     78
# 817350  Inconsistent Mapping  Inconsistent Mapping                    102
# 817361  Inconsistent Mapping  Inconsistent Mapping                    151
# 817370  Inconsistent Mapping  Inconsistent Mapping                    885
# 817388  Inconsistent Mapping  Inconsistent Mapping                     39
#
#        appointment_month
# 12               2021-08
# 15               2021-08
# 17               2021-08
# 38               2021-08
# 43               2021-08
# ...                  ...
# 817344           2022-06
# 817350           2022-06
# 817361           2022-06
# 817370           2022-06
# 817388           2022-06
#
# [89494 rows x 8 columns]

# %%
# Filter the 'nc' DataFrame according to wrong values.
# There are wrong values in the 'national_category' column, identified as 'Inconsistent Mapping' and 'Unmapped'.

nc[nc['context_type'].str.contains('Unmapped')]
# Out:
#        appointment_date icb_ons_code  \
# 6            2021-08-02    E54000050
# 36           2021-08-03    E54000050
# 65           2021-08-04    E54000050
# 92           2021-08-05    E54000050
# 130          2021-08-06    E54000050
# ...                 ...          ...
# 817213       2022-06-25    E54000054
# 817253       2022-06-27    E54000054
# 817279       2022-06-28    E54000054
# 817305       2022-06-29    E54000054
# 817349       2022-06-30    E54000054
#
#                              sub_icb_location_name service_setting  \
# 6       NHS North East and North Cumbria ICB - 00L        Unmapped
# 36      NHS North East and North Cumbria ICB - 00L        Unmapped
# 65      NHS North East and North Cumbria ICB - 00L        Unmapped
# 92      NHS North East and North Cumbria ICB - 00L        Unmapped
# 130     NHS North East and North Cumbria ICB - 00L        Unmapped
# ...                                            ...             ...
# 817213              NHS West Yorkshire ICB - X2C4Y        Unmapped
# 817253              NHS West Yorkshire ICB - X2C4Y        Unmapped
# 817279              NHS West Yorkshire ICB - X2C4Y        Unmapped
# 817305              NHS West Yorkshire ICB - X2C4Y        Unmapped
# 817349              NHS West Yorkshire ICB - X2C4Y        Unmapped
#
#        context_type national_category  count_of_appointments appointment_month
# 6          Unmapped          Unmapped                    372           2021-08
# 36         Unmapped          Unmapped                    362           2021-08
# 65         Unmapped          Unmapped                    336           2021-08
# 92         Unmapped          Unmapped                    394           2021-08
# 130        Unmapped          Unmapped                    302           2021-08
# ...             ...               ...                    ...               ...
# 817213     Unmapped          Unmapped                      1           2022-06
# 817253     Unmapped          Unmapped                    225           2022-06
# 817279     Unmapped          Unmapped                    176           2022-06
# 817305     Unmapped          Unmapped                    146           2022-06
# 817349     Unmapped          Unmapped                    186           2022-06
#
# [27419 rows x 8 columns]

# %%
nc[nc['context_type'].str.contains('Inconsistent Mapping')]
# Out:
#        appointment_date icb_ons_code  \
# 12           2021-08-02    E54000050
# 15           2021-08-02    E54000050
# 17           2021-08-02    E54000050
# 38           2021-08-03    E54000050
# 43           2021-08-03    E54000050
# ...                 ...          ...
# 817344       2022-06-29    E54000054
# 817350       2022-06-30    E54000054
# 817361       2022-06-30    E54000054
# 817370       2022-06-30    E54000054
# 817388       2022-06-30    E54000054
#
#                              sub_icb_location_name            service_setting  \
# 12      NHS North East and North Cumbria ICB - 00L           General Practice
# 15      NHS North East and North Cumbria ICB - 00L  Extended Access Provision
# 17      NHS North East and North Cumbria ICB - 00L                      Other
# 38      NHS North East and North Cumbria ICB - 00L                      Other
# 43      NHS North East and North Cumbria ICB - 00L           General Practice
# ...                                            ...                        ...
# 817344              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
# 817350              NHS West Yorkshire ICB - X2C4Y       Primary Care Network
# 817361              NHS West Yorkshire ICB - X2C4Y                      Other
# 817370              NHS West Yorkshire ICB - X2C4Y           General Practice
# 817388              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
#
#                 context_type     national_category  count_of_appointments  \
# 12      Inconsistent Mapping  Inconsistent Mapping                    619
# 15      Inconsistent Mapping  Inconsistent Mapping                      1
# 17      Inconsistent Mapping  Inconsistent Mapping                    194
# 38      Inconsistent Mapping  Inconsistent Mapping                    170
# 43      Inconsistent Mapping  Inconsistent Mapping                    610
# ...                      ...                   ...                    ...
# 817344  Inconsistent Mapping  Inconsistent Mapping                     78
# 817350  Inconsistent Mapping  Inconsistent Mapping                    102
# 817361  Inconsistent Mapping  Inconsistent Mapping                    151
# 817370  Inconsistent Mapping  Inconsistent Mapping                    885
# 817388  Inconsistent Mapping  Inconsistent Mapping                     39
#
#        appointment_month
# 12               2021-08
# 15               2021-08
# 17               2021-08
# 38               2021-08
# 43               2021-08
# ...                  ...
# 817344           2022-06
# 817350           2022-06
# 817361           2022-06
# 817370           2022-06
# 817388           2022-06
#
# [89494 rows x 8 columns]

# %%
# Determine the descriptive statistics of the 'nc' DataFrame.
nc.describe()
# Out:
#        count_of_appointments
# count          817394.000000
# mean              362.183684
# std              1084.576600
# min                 1.000000
# 25%                 7.000000
# 50%                25.000000
# 75%               128.000000
# max             16590.000000

# %%
# Determine the metadata of the 'nc' DataFrame.
nc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 817394 entries, 0 to 817393
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   appointment_date       817394 non-null  datetime64[ns]
#  1   icb_ons_code           817394 non-null  object
#  2   sub_icb_location_name  817394 non-null  object
#  3   service_setting        817394 non-null  object
#  4   context_type           817394 non-null  object
#  5   national_category      817394 non-null  object
#  6   count_of_appointments  817394 non-null  int64
#  7   appointment_month      817394 non-null  object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 49.9+ MB

# %%
# Determine the descriptive statistics of the 'ar' DataFrame.
ar.describe()
# Out:
#        count_of_appointments
# count          596821.000000
# mean             1244.601857
# std              5856.887042
# min                 1.000000
# 25%                 7.000000
# 50%                47.000000
# 75%               308.000000
# max            211265.000000

# %%
# Determine the metadata of the 'ar' DataFrame.
ar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 596821 entries, 0 to 596820
# Data columns (total 7 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   icb_ons_code                       596821 non-null  object
#  1   appointment_month                  596821 non-null  object
#  2   appointment_status                 596821 non-null  object
#  3   hcp_type                           596821 non-null  object
#  4   appointment_mode                   596821 non-null  object
#  5   time_between_book_and_appointment  596821 non-null  object
#  6   count_of_appointments              596821 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 31.9+ MB

# %%
# Determine the descriptive statistics of the 'ad' DataFrame.
ad.describe()
# Out:
#        count_of_appointments
# count          137793.000000
# mean             1219.080011
# std              1546.902956
# min                 1.000000
# 25%               194.000000
# 50%               696.000000
# 75%              1621.000000
# max             15400.000000

# %%
# Determine the metadata of the 'ad' DataFrame.
ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137793 entries, 0 to 137792
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   sub_icb_location_code      137793 non-null  object
#  1   sub_icb_location_ons_code  137793 non-null  object
#  2   sub_icb_location_name      137793 non-null  object
#  3   icb_ons_code               137793 non-null  object
#  4   region_ons_code            137793 non-null  object
#  5   appointment_date           137793 non-null  object
#  6   actual_duration            137793 non-null  object
#  7   count_of_appointments      137793 non-null  int64
# dtypes: int64(1), object(7)
# memory usage: 8.4+ MB

# %%
# Import the necessary packages.
import pandas as pd

# Read the Excel file.
# Assign a variable.
# Use the pd.read_excel() function.
# Specify the name of the Excel file.
nc = pd.read_excel('national_categories.xlsx')

# Print the DataFrame.
nc
# Out:
#        appointment_date icb_ons_code  \
# 0            2021-08-02    E54000050
# 1            2021-08-02    E54000050
# 2            2021-08-02    E54000050
# 3            2021-08-02    E54000050
# 4            2021-08-02    E54000050
# ...                 ...          ...
# 817389       2022-06-30    E54000054
# 817390       2022-06-30    E54000054
# 817391       2022-06-30    E54000054
# 817392       2022-06-30    E54000054
# 817393       2022-06-30    E54000054
#
#                              sub_icb_location_name            service_setting  \
# 0       NHS North East and North Cumbria ICB - 00L       Primary Care Network
# 1       NHS North East and North Cumbria ICB - 00L                      Other
# 2       NHS North East and North Cumbria ICB - 00L           General Practice
# 3       NHS North East and North Cumbria ICB - 00L           General Practice
# 4       NHS North East and North Cumbria ICB - 00L           General Practice
# ...                                            ...                        ...
# 817389              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
# 817390              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
# 817391              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
# 817392              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
# 817393              NHS West Yorkshire ICB - X2C4Y  Extended Access Provision
#
#                   context_type                       national_category  \
# 0       Care Related Encounter  Patient contact during Care Home Round
# 1       Care Related Encounter                         Planned Clinics
# 2       Care Related Encounter                              Home Visit
# 3       Care Related Encounter              General Consultation Acute
# 4       Care Related Encounter            Structured Medication Review
# ...                        ...                                     ...
# 817389  Care Related Encounter             Unplanned Clinical Activity
# 817390  Care Related Encounter                         Planned Clinics
# 817391  Care Related Encounter              Planned Clinical Procedure
# 817392  Care Related Encounter            General Consultation Routine
# 817393  Care Related Encounter              General Consultation Acute
#
#         count_of_appointments appointment_month
# 0                           3           2021-08
# 1                           7           2021-08
# 2                          79           2021-08
# 3                         725           2021-08
# 4                           2           2021-08
# ...                       ...               ...
# 817389                     12           2022-06
# 817390                      4           2022-06
# 817391                     92           2022-06
# 817392                      4           2022-06
# 817393                     19           2022-06
#
# [817394 rows x 8 columns]

# %%
# Read the CSV file.
# Assign a variable.
# Use the pd.read_csv() function.
# Specify the name of the CSV file.
ar = pd.read_csv('appointments_regional.csv')

# Print the DataFrame.
ar
# Out:
#        icb_ons_code appointment_month appointment_status hcp_type  \
# 0         E54000034           2020-01           Attended       GP
# 1         E54000034           2020-01           Attended       GP
# 2         E54000034           2020-01           Attended       GP
# 3         E54000034           2020-01           Attended       GP
# 4         E54000034           2020-01           Attended       GP
# ...             ...               ...                ...      ...
# 596816    E54000050           2022-06            Unknown  Unknown
# 596817    E54000050           2022-06            Unknown  Unknown
# 596818    E54000050           2022-06            Unknown  Unknown
# 596819    E54000050           2022-06            Unknown  Unknown
# 596820    E54000050           2022-06            Unknown  Unknown
#
#        appointment_mode time_between_book_and_appointment  \
# 0          Face-to-Face                             1 Day
# 1          Face-to-Face                    15  to 21 Days
# 2          Face-to-Face                       2 to 7 Days
# 3          Face-to-Face                    22  to 28 Days
# 4          Face-to-Face                     8  to 14 Days
# ...                 ...                               ...
# 596816          Unknown                       2 to 7 Days
# 596817          Unknown                    22  to 28 Days
# 596818          Unknown                     8  to 14 Days
# 596819          Unknown                 More than 28 Days
# 596820          Unknown                          Same Day
#
#         count_of_appointments
# 0                        8107
# 1                        6791
# 2                       20686
# 3                        4268
# 4                       11971
# ...                       ...
# 596816                     21
# 596817                      8
# 596818                     28
# 596819                     17
# 596820                     10
#
# [596821 rows x 7 columns]

# %%
# Read the CSV file.
# Assign a variable.
# Use the pd.read_csv() function.
# Specify the name of the CSV file.
ad = pd.read_csv('actual_duration.csv')

# Print the DataFrame.
ad
# Out:
#        sub_icb_location_code sub_icb_location_ons_code  \
# 0                        00L                 E38000130
# 1                        00L                 E38000130
# 2                        00L                 E38000130
# 3                        00L                 E38000130
# 4                        00L                 E38000130
# ...                      ...                       ...
# 137788                 X2C4Y                 E38000254
# 137789                 X2C4Y                 E38000254
# 137790                 X2C4Y                 E38000254
# 137791                 X2C4Y                 E38000254
# 137792                 X2C4Y                 E38000254
#
#                              sub_icb_location_name icb_ons_code  \
# 0       NHS North East and North Cumbria ICB - 00L    E54000050
# 1       NHS North East and North Cumbria ICB - 00L    E54000050
# 2       NHS North East and North Cumbria ICB - 00L    E54000050
# 3       NHS North East and North Cumbria ICB - 00L    E54000050
# 4       NHS North East and North Cumbria ICB - 00L    E54000050
# ...                                            ...          ...
# 137788              NHS West Yorkshire ICB - X2C4Y    E54000054
# 137789              NHS West Yorkshire ICB - X2C4Y    E54000054
# 137790              NHS West Yorkshire ICB - X2C4Y    E54000054
# 137791              NHS West Yorkshire ICB - X2C4Y    E54000054
# 137792              NHS West Yorkshire ICB - X2C4Y    E54000054
#
#        region_ons_code appointment_date         actual_duration  \
# 0            E40000012        01-Dec-21           31-60 Minutes
# 1            E40000012        01-Dec-21           21-30 Minutes
# 2            E40000012        01-Dec-21            6-10 Minutes
# 3            E40000012        01-Dec-21  Unknown / Data Quality
# 4            E40000012        01-Dec-21           16-20 Minutes
# ...                ...              ...                     ...
# 137788       E40000012        30-Jun-22           31-60 Minutes
# 137789       E40000012        30-Jun-22           21-30 Minutes
# 137790       E40000012        30-Jun-22           16-20 Minutes
# 137791       E40000012        30-Jun-22           11-15 Minutes
# 137792       E40000012        30-Jun-22             1-5 Minutes
#
#         count_of_appointments
# 0                         364
# 1                         619
# 2                        1698
# 3                        1277
# 4                         730
# ...                       ...
# 137788                    430
# 137789                    751
# 137790                    921
# 137791                   1439
# 137792                   1739
#
# [137793 rows x 8 columns]

# %%
# Get Unique Count of Locations from the 'nc' DataFrame.
count = nc.sub_icb_location_name.unique().size
print("Count of locations : "+ str(count))
# Out:
# Count of locations : 106

# %%
# Get Unique Count of Locations from the 'ad' DataFrame.
count = ad.sub_icb_location_name.unique().size
print("Count of locations : "+ str(count))
# Out:
# Count of locations : 106

# %%
# Determine the 5 locations with the highest number of records.
print(len(ad['sub_icb_location_name'].unique()))
# Out:
# 106

# %%
# Determine the number of service settings from the 'nc' DataFrame.
print(len(nc['service_setting'].unique()))
# Out:
# 5

# %%
# Determine the number of context types from the 'nc' DataFrame.
print(len(nc['context_type'].unique()))
# Out:
# 3

# %%
# Determine the number of national categories from the 'nc' DataFrame.
print(len(nc['national_category'].unique()))
# Out:
# 18

# %%
# Determine the number of appointment statuses from the 'ar' DataFrame.
print(len(ar['appointment_status'].unique()))
# Out:
# 3

# %%
# Sorting the data by 'count_of_appointments' to find the 5 locations with the highest number of records.
nc.sort_values(by=['count_of_appointments'], ascending=False)
# Out:
#        appointment_date icb_ons_code  \
# 732144       2022-05-09    E54000029
# 732705       2022-05-23    E54000029
# 724735       2021-10-11    E54000029
# 724978       2021-10-18    E54000029
# 732446       2022-05-16    E54000029
# ...                 ...          ...
# 671395       2022-06-26    E54000040
# 671432       2022-06-27    E54000040
# 671444       2022-06-27    E54000040
# 671480       2022-06-28    E54000040
# 671540       2022-06-29    E54000040
#
#                                     sub_icb_location_name  \
# 732144                  NHS North East London ICB - A3A8R
# 732705                  NHS North East London ICB - A3A8R
# 724735                  NHS North East London ICB - A3A8R
# 724978                  NHS North East London ICB - A3A8R
# 732446                  NHS North East London ICB - A3A8R
# ...                                                   ...
# 671395  NHS Bath and North East Somerset Swindon and W...
# 671432  NHS Bath and North East Somerset Swindon and W...
# 671444  NHS Bath and North East Somerset Swindon and W...
# 671480  NHS Bath and North East Somerset Swindon and W...
# 671540  NHS Bath and North East Somerset Swindon and W...
#
#                   service_setting            context_type  \
# 732144           General Practice  Care Related Encounter
# 732705           General Practice  Care Related Encounter
# 724735           General Practice  Care Related Encounter
# 724978           General Practice  Care Related Encounter
# 732446           General Practice  Care Related Encounter
# ...                           ...                     ...
# 671395           General Practice  Care Related Encounter
# 671432           General Practice  Care Related Encounter
# 671444  Extended Access Provision  Care Related Encounter
# 671480           General Practice  Care Related Encounter
# 671540  Extended Access Provision  Care Related Encounter
#
#                              national_category  count_of_appointments  \
# 732144            General Consultation Routine                  16590
# 732705            General Consultation Routine                  16527
# 724735            General Consultation Routine                  16495
# 724978            General Consultation Routine                  16492
# 732446            General Consultation Routine                  16412
# ...                                        ...                    ...
# 671395            General Consultation Routine                      1
# 671432  Group Consultation and Group Education                      1
# 671444              Planned Clinical Procedure                      1
# 671480  Group Consultation and Group Education                      1
# 671540         Non-contractual chargeable work                      1
#
#        appointment_month
# 732144           2022-05
# 732705           2022-05
# 724735           2021-10
# 724978           2021-10
# 732446           2022-05
# ...                  ...
# 671395           2022-06
# 671432           2022-06
# 671444           2022-06
# 671480           2022-06
# 671540           2022-06
#
# [817394 rows x 8 columns]

# %%
nc[['sub_icb_location_name', 'count_of_appointments']].value_counts().reset_index(name='count')
# Out:
#                                     sub_icb_location_name  \
# 0                        NHS Greater Manchester ICB - 01D
# 1              NHS Lancashire and South Cumbria ICB - 01K
# 2          NHS Staffordshire and Stoke-on-Trent ICB - 05W
# 3       NHS Buckinghamshire Oxfordshire and Berkshire ...
# 4              NHS North East and North Cumbria ICB - 01H
# ...                                                   ...
# 130760                  NHS Mid and South Essex ICB - 99E
# 130761                  NHS Mid and South Essex ICB - 99E
# 130762                  NHS Mid and South Essex ICB - 99E
# 130763                  NHS Mid and South Essex ICB - 99E
# 130764                     NHS West Yorkshire ICB - X2C4Y
#
#         count_of_appointments  count
# 0                           1    851
# 1                           1    793
# 2                           1    788
# 3                           1    783
# 4                           1    755
# ...                       ...    ...
# 130760                    866      1
# 130761                    865      1
# 130762                    861      1
# 130763                    855      1
# 130764                   4203      1
#
# [130765 rows x 3 columns]

# %%
nc[['sub_icb_location_name', 'count_of_appointments']].value_counts()
# Out:
# sub_icb_location_name                                         count_of_appointments
# NHS Greater Manchester ICB - 01D                              1                        851
# NHS Lancashire and South Cumbria ICB - 01K                    1                        793
# NHS Staffordshire and Stoke-on-Trent ICB - 05W                1                        788
# NHS Buckinghamshire Oxfordshire and Berkshire West ICB - 10Q  1                        783
# NHS North East and North Cumbria ICB - 01H                    1                        755
#                                                                                       ...
# NHS Mid and South Essex ICB - 99E                             866                        1
#                                                               865                        1
#                                                               861                        1
#                                                               855                        1
# NHS West Yorkshire ICB - X2C4Y                                4203                       1
# Length: 130765, dtype: int64

# %%
nc.sort_values(by=['count_of_appointments'], ascending=False)
